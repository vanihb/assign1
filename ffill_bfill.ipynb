# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/VANI/Downloads/supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw          NaN  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# 2        Home and lifestyle       46.33       7.0  16.2155   340.5255
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customertype               2
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   3
# Tax 5%                     0
# Total                      0
# Date                       2
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.Quantity=df.Quantity.fillna(df.Quantity.mean())

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customertype  Gender            Product line  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw          NaN  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw       Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon          NaN  Female  Electronic accessories
# 7  315-22-5665      C  Naypyitaw       Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon       Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay       Member  Female      Food and beverages
#
#    Unit price   Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
df.bfill(axis='rows')
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line  Unit price   Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69   7.000000  26.1415   548.9715
# 1    Electronic accessories       15.28   5.000000   3.8200    80.2200
# 2        Home and lifestyle       46.33   7.000000  16.2155   340.5255
# ...

# %%
df.bfill(axis='columns')
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Female  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty      74.69       7.0  26.1415  548.9715
# 1    Electronic accessories      15.28       5.0     3.82     80.22
# 2        Home and lifestyle      46.33       7.0  16.2155  340.5255
# ...

# %%
df=pd.read_csv("C:/Users/VANI/Downloads/supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw          NaN  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# 2        Home and lifestyle       46.33       7.0  16.2155   340.5255
# ...

# %%
df.ffill(axis=0)
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Member  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# 2        Home and lifestyle       46.33       7.0  16.2155   340.5255
# ...

# %%
df.ffill(axis=1)
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw    Naypyitaw  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line Unit price Quantity   Tax 5%     Total  \
# 0         Health and beauty      74.69      7.0  26.1415  548.9715
# 1    Electronic accessories      15.28      5.0     3.82     80.22
# 2        Home and lifestyle      46.33      7.0  16.2155  340.5255
# ...

# %%
df=pd.read_csv("C:/Users/VANI/Downloads/supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customertype  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw          NaN  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69       7.0  26.1415   548.9715
# 1    Electronic accessories       15.28       5.0   3.8200    80.2200
# 2        Home and lifestyle       46.33       7.0  16.2155   340.5255
# ...

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customertype  Gender            Product line  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw          NaN  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw       Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon          NaN  Female  Electronic accessories
# 7  315-22-5665      C  Naypyitaw       Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon       Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay       Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
df=pd.read_csv("C:/Users/VANI/Downloads/supermarket_sales - Sheet1.csv")

# %%
ip=SimpleImputer(strategy='most_frequent')
df.Date=ip.fit_transform(df['Date'].values.reshape(-1,1))[:,0]
df.head(10)
# Out:
#     Invoice ID Branch       City Customertype  Gender            Product line  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw          NaN  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw       Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon          NaN  Female  Electronic accessories
# 7  315-22-5665      C  Naypyitaw       Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon       Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay       Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
df=pd.read_csv("C:/Users/VANI/Downloads/supermarket_sales - Sheet1.csv")

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customertype  Gender            Product line  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw          NaN  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal     NaN      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw       Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon          NaN     NaN  Electronic accessories
# 7  315-22-5665      C  Naypyitaw       Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon       Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay       Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...

# %%
ip=SimpleImputer(strategy='constant',fill_value='Female')
df.Gender=ip.fit_transform(df['Gender'].values.reshape(-1,1))[:,0]
df.head(10)
# Out:
#     Invoice ID Branch       City Customertype  Gender            Product line  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw          NaN  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal  Female      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
# 5  699-14-3026      C  Naypyitaw       Normal    Male  Electronic accessories
# 6  355-53-5943      A     Yangon          NaN  Female  Electronic accessories
# 7  315-22-5665      C  Naypyitaw       Normal  Female      Home and lifestyle
# 8  665-32-9167      A     Yangon       Member  Female       Health and beauty
# 9  692-92-5582      B   Mandalay       Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total        Date   Time      Payment  \
# ...
